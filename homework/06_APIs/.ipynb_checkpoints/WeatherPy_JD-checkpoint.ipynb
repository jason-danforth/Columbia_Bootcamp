# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
api_key = '05c56b4405b3fde15b801034b905b134'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
# confirm list of cities is non-repeating 
s = set(cities)
len(s)
# Out:
# 624

# %%
cities[0]
# Out:
# 'mahibadhoo'

# %%
cities[-1]
# Out:
# 'la ronge'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city = cities[0] 
url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={api_key}'
response = requests.get(url).json()

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 3.78, 'lon': 72.97},
#  'dt': 1566078452,
#  'id': 1337605,
#  'main': {'grnd_level': 1009.48,
#           'humidity': 76,
#           'pressure': 1009.46,
#           'sea_level': 1009.46,
#           'temp': 300.931,
#           'temp_max': 300.931,
#           'temp_min': 300.931},
#  'name': 'Mahibadhoo',
#  'sys': {'country': 'MV',
#          'message': 0.0064,
#          'sunrise': 1566090316,
#          'sunset': 1566134355},
#  'timezone': 18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 22.199, 'speed': 3.03}}

# %%
response.get('wind').get('speed')
# Out:
# 3.03

# %%
min(5, 2)
# Out:
# 2

# %%
Cloudiness = []
Humidity = []
Wind_Speed = []
Max_Temp = []
Name = []
Lat = []
Lon = []

for num, city in enumerate(cities):
    # Make API call
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={api_key}'
    response = requests.get(url).json()
    
    # Test whether call was successful
    if response.get('cod') == '404':
        print(f'ERROR: could not find record for {city}, city #{num}')
    else:
        print(f'Recording values for {city}, city #{num}.')
        
        Name.append(city)
        
        # Temperature
        if response.get('main').get('temp_max') is not None:
            # Convert temp from Kelvin to Fahrenheit
            temp = round((response.get('main').get('temp_max') - 273.15) * 9/5 + 32, 2)
            Max_Temp.append(temp)
        else:
            Max_Temp.append(0)

        # Humidity
        if response.get('main').get('humidity') is not None:
            humidity = min(round(response.get('main').get('humidity'), 0), 100.00)
            Humidity.append(humidity)
        else:
            Humidity.append(0)

        # Cloudiness
        if response.get('clouds').get('all') is not None:
            clouds = min(response.get('clouds').get('all'), 100)
            Cloudiness.append(clouds)
        else:
            Cloudiness.append(0)

        # Wind
        if response.get('wind').get('speed') is not None:
            wind = round(response.get('wind').get('speed'), 2)
            Wind_Speed.append(wind)
        else:
            Wind_Speed.append(0)

        # Latitude
        if response.get('coord').get('lat') is not None:
            latitude = response.get('coord').get('lat')
            Lat.append(latitude)
        else:
            Lat.append(0)

        # Longitude
        if response.get('coord').get('lon') is not None:
            longitude = response.get('coord').get('lon')
            Lon.append(longitude)
# Out:
# Recording values for mahibadhoo, city #0.
# Recording values for klaksvik, city #1.
# Recording values for zhangjiakou, city #2.
# Recording values for solwezi, city #3.
# Recording values for atuona, city #4.
# Recording values for torbay, city #5.
# Recording values for muros, city #6.
# Recording values for barrow, city #7.
# Recording values for margate, city #8.
# Recording values for punta arenas, city #9.
# Recording values for rikitea, city #10.
# Recording values for mataura, city #11.
# Recording values for hobart, city #12.
# Recording values for tasiilaq, city #13.
# Recording values for hilo, city #14.
# Recording values for naze, city #15.
# Recording values for oktyabrskoye, city #16.
# Recording values for sitka, city #17.
# Recording values for madaoua, city #18.
# Recording values for dikson, city #19.
# ERROR: could not find record for vitoria da conquista, city #20
# Recording values for sao pedro, city #21.
# Recording values for cidreira, city #22.
# Recording values for nome, city #23.
# ERROR: could not find record for meyungs, city #24
# ERROR: could not find record for severnyy, city #25
# Recording values for nehe, city #26.
# Recording values for velyka pysarivka, city #27.
# Recording values for jamestown, city #28.
# Recording values for ouango, city #29.
# Recording values for busselton, city #30.
# Recording values for port elizabeth, city #31.
# Recording values for severo-kurilsk, city #32.
# Recording values for bluff, city #33.
# Recording values for albany, city #34.
# Recording values for ushuaia, city #35.
# Recording values for katete, city #36.
# Recording values for fare, city #37.
# Recording values for lebu, city #38.
# Recording values for ponta delgada, city #39.
# ERROR: could not find record for grand river south east, city #40
# Recording values for bethel, city #41.
# Recording values for kant, city #42.
# Recording values for ejura, city #43.
# Recording values for faya, city #44.
# Recording values for airai, city #45.
# Recording values for cape town, city #46.
# Recording values for saskylakh, city #47.
# Recording values for yerbogachen, city #48.
# Recording values for santa maria, city #49.
# Recording values for vaini, city #50.
# Recording values for east liverpool, city #51.
# Recording values for san patricio, city #52.
# Recording values for kindu, city #53.
# Recording values for tuatapere, city #54.
# ERROR: could not find record for kuche, city #55
# Recording values for miri, city #56.
# Recording values for mar del plata, city #57.
# Recording values for sola, city #58.
# Recording values for ust-maya, city #59.
# Recording values for coquimbo, city #60.
# Recording values for bredasdorp, city #61.
# Recording values for chuy, city #62.
# Recording values for piraju, city #63.
# Recording values for porto novo, city #64.
# Recording values for oistins, city #65.
# Recording values for piranhas, city #66.
# Recording values for acapulco, city #67.
# Recording values for tshikapa, city #68.
# Recording values for derzhavinsk, city #69.
# ERROR: could not find record for amderma, city #70
# Recording values for mende, city #71.
# Recording values for tsuyama, city #72.
# Recording values for pisco, city #73.
# Recording values for namtsy, city #74.
# Recording values for ponta do sol, city #75.
# Recording values for mitu, city #76.
# Recording values for ribeira grande, city #77.
# Recording values for pevek, city #78.
# Recording values for thompson, city #79.
# Recording values for sokoni, city #80.
# Recording values for broome, city #81.
# Recording values for yinchuan, city #82.
# ERROR: could not find record for doctor pedro p. pena, city #83
# Recording values for new norfolk, city #84.
# Recording values for bulungu, city #85.
# Recording values for lagoa, city #86.
# ERROR: could not find record for belushya guba, city #87
# Recording values for cherskiy, city #88.
# Recording values for kapaa, city #89.
# Recording values for hambantota, city #90.
# ERROR: could not find record for taolanaro, city #91
# Recording values for karratha, city #92.
# Recording values for souillac, city #93.
# Recording values for puerto ayora, city #94.
# Recording values for lagunas, city #95.
# Recording values for guerrero negro, city #96.
# Recording values for east london, city #97.
# Recording values for carauari, city #98.
# Recording values for warrnambool, city #99.
# Recording values for tambovka, city #100.
# Recording values for batu, city #101.
# Recording values for maragogi, city #102.
# Recording values for poum, city #103.
# Recording values for lompoc, city #104.
# Recording values for isangel, city #105.
# Recording values for manta, city #106.
# Recording values for otane, city #107.
# Recording values for havelock, city #108.
# Recording values for tete, city #109.
# Recording values for marawi, city #110.
# ERROR: could not find record for bur gabo, city #111
# Recording values for yellowknife, city #112.
# Recording values for cap-aux-meules, city #113.
# Recording values for hithadhoo, city #114.
# Recording values for zhigansk, city #115.
# ERROR: could not find record for rungata, city #116
# Recording values for oskaloosa, city #117.
# Recording values for hermanus, city #118.
# Recording values for spasskoye, city #119.
# Recording values for magadan, city #120.
# Recording values for mana, city #121.
# Recording values for georgetown, city #122.
# Recording values for udaipura, city #123.
# Recording values for college, city #124.
# Recording values for clyde, city #125.
# Recording values for codrington, city #126.
# Recording values for pacific grove, city #127.
# Recording values for qax, city #128.
# Recording values for joshimath, city #129.
# Recording values for nouadhibou, city #130.
# ERROR: could not find record for saleaula, city #131
# ERROR: could not find record for matsanga, city #132
# Recording values for kodiak, city #133.
# Recording values for puerto cabezas, city #134.
# ERROR: could not find record for marcona, city #135
# Recording values for yar-sale, city #136.
# Recording values for chokurdakh, city #137.
# Recording values for qaanaaq, city #138.
# Recording values for popondetta, city #139.
# ERROR: could not find record for tumannyy, city #140
# ERROR: could not find record for bengkulu, city #141
# Recording values for norrtalje, city #142.
# Recording values for rovaniemi, city #143.
# Recording values for marsh harbour, city #144.
# Recording values for magway, city #145.
# Recording values for castro, city #146.
# Recording values for arraial do cabo, city #147.
# Recording values for vanavara, city #148.
# Recording values for nizhneivkino, city #149.
# Recording values for itoman, city #150.
# Recording values for charlestown, city #151.
# Recording values for tuban, city #152.
# ERROR: could not find record for saryshagan, city #153
# Recording values for upernavik, city #154.
# Recording values for grand gaube, city #155.
# Recording values for paita, city #156.
# Recording values for omsukchan, city #157.
# Recording values for ilulissat, city #158.
# Recording values for mahebourg, city #159.
# Recording values for saint-philippe, city #160.
# ERROR: could not find record for rudbar, city #161
# ERROR: could not find record for sentyabrskiy, city #162
# Recording values for victoria, city #163.
# Recording values for new ulm, city #164.
# Recording values for tiksi, city #165.
# ERROR: could not find record for gurgan, city #166
# Recording values for nuuk, city #167.
# Recording values for luderitz, city #168.
# Recording values for touros, city #169.
# ERROR: could not find record for tambopata, city #170
# Recording values for kaitangata, city #171.
# Recording values for ballina, city #172.
# ERROR: could not find record for tsihombe, city #173
# Recording values for avarua, city #174.
# Recording values for mount gambier, city #175.
# Recording values for chapleau, city #176.
# Recording values for bloemfontein, city #177.
# Recording values for constitucion, city #178.
# Recording values for port blair, city #179.
# Recording values for norman wells, city #180.
# Recording values for coihaique, city #181.
# Recording values for orlik, city #182.
# Recording values for padang, city #183.
# Recording values for dimovo, city #184.
# Recording values for gurlan, city #185.
# Recording values for nikolskoye, city #186.
# Recording values for burhaniye, city #187.
# Recording values for pyinmana, city #188.
# Recording values for mandalgovi, city #189.
# Recording values for namibe, city #190.
# Recording values for coatzacoalcos, city #191.
# ERROR: could not find record for skalistyy, city #192
# Recording values for faanui, city #193.
# Recording values for hofn, city #194.
# ERROR: could not find record for vreed en hoop, city #195
# Recording values for port alfred, city #196.
# Recording values for ostrovnoy, city #197.
# Recording values for bubaque, city #198.
# Recording values for port macquarie, city #199.
# Recording values for pyaozerskiy, city #200.
# Recording values for lorengau, city #201.
# Recording values for barguzin, city #202.
# Recording values for dingzhou, city #203.
# Recording values for butaritari, city #204.
# Recording values for cayenne, city #205.
# Recording values for khatanga, city #206.
# Recording values for kashary, city #207.
# Recording values for plettenberg bay, city #208.
# Recording values for narsaq, city #209.
# Recording values for parit buntar, city #210.
# Recording values for ihosy, city #211.
# Recording values for hami, city #212.
# Recording values for constantine, city #213.
# Recording values for provideniya, city #214.
# Recording values for biloli, city #215.
# Recording values for kidal, city #216.
# Recording values for san quintin, city #217.
# Recording values for vakhrushev, city #218.
# Recording values for cabedelo, city #219.
# Recording values for terrace, city #220.
# ERROR: could not find record for bairiki, city #221
# Recording values for manuk mangkaw, city #222.
# Recording values for salalah, city #223.
# Recording values for doha, city #224.
# Recording values for kruisfontein, city #225.
# Recording values for port shepstone, city #226.
# Recording values for mehamn, city #227.
# ERROR: could not find record for svetlyy, city #228
# Recording values for tiznit, city #229.
# Recording values for praia, city #230.
# Recording values for samarai, city #231.
# Recording values for san juan, city #232.
# Recording values for ixtapa, city #233.
# Recording values for port hardy, city #234.
# Recording values for iqaluit, city #235.
# Recording values for ahipara, city #236.
# Recording values for leningradskiy, city #237.
# Recording values for tuktoyaktuk, city #238.
# Recording values for vyshestebliyevskaya, city #239.
# Recording values for coahuayana, city #240.
# Recording values for carnarvon, city #241.
# Recording values for ayagoz, city #242.
# Recording values for dingle, city #243.
# Recording values for solnechnyy, city #244.
# Recording values for charters towers, city #245.
# Recording values for riyadh, city #246.
# Recording values for tara, city #247.
# Recording values for dunedin, city #248.
# Recording values for hobyo, city #249.
# ERROR: could not find record for vaitupu, city #250
# Recording values for tezu, city #251.
# Recording values for alpena, city #252.
# Recording values for changping, city #253.
# Recording values for ulladulla, city #254.
# Recording values for tandil, city #255.
# Recording values for quelimane, city #256.
# Recording values for joplin, city #257.
# Recording values for saldanha, city #258.
# Recording values for menemen, city #259.
# Recording values for lar, city #260.
# Recording values for oksfjord, city #261.
# Recording values for skjervoy, city #262.
# Recording values for pathum thani, city #263.
# Recording values for verkhoyansk, city #264.
# Recording values for kaeo, city #265.
# Recording values for keti bandar, city #266.
# Recording values for mitsamiouli, city #267.
# Recording values for saint george, city #268.
# Recording values for vostok, city #269.
# Recording values for kavieng, city #270.
# Recording values for dillon, city #271.
# ERROR: could not find record for illoqqortoormiut, city #272
# Recording values for walvis bay, city #273.
# Recording values for katsuura, city #274.
# Recording values for high level, city #275.
# Recording values for xiashi, city #276.
# ERROR: could not find record for samusu, city #277
# Recording values for shiyan, city #278.
# Recording values for morondava, city #279.
# Recording values for haines junction, city #280.
# Recording values for srednekolymsk, city #281.
# Recording values for hernani, city #282.
# Recording values for kouango, city #283.
# Recording values for ancud, city #284.
# Recording values for nimaparha, city #285.
# Recording values for brae, city #286.
# Recording values for klyuchi, city #287.
# Recording values for hillsborough, city #288.
# ERROR: could not find record for mullaitivu, city #289
# Recording values for meulaboh, city #290.
# Recording values for leshukonskoye, city #291.
# Recording values for kiboga, city #292.
# Recording values for lexington, city #293.
# Recording values for yumen, city #294.
# Recording values for henties bay, city #295.
# Recording values for ca mau, city #296.
# Recording values for muravlenko, city #297.
# Recording values for aiken, city #298.
# Recording values for cabo san lucas, city #299.
# Recording values for creel, city #300.
# Recording values for vila, city #301.
# Recording values for saint-georges, city #302.
# Recording values for great falls, city #303.
# Recording values for pitimbu, city #304.
# ERROR: could not find record for cam pha, city #305
# Recording values for rocha, city #306.
# Recording values for dauphin, city #307.
# Recording values for sao joao da barra, city #308.
# Recording values for libertador general san martin, city #309.
# Recording values for huarmey, city #310.
# Recording values for vuktyl, city #311.
# Recording values for saint-francois, city #312.
# Recording values for jining, city #313.
# Recording values for pangody, city #314.
# Recording values for le vauclin, city #315.
# ERROR: could not find record for bolshiye uki, city #316
# ERROR: could not find record for olafsvik, city #317
# Recording values for lhokseumawe, city #318.
# ERROR: could not find record for eldikan, city #319
# Recording values for praya, city #320.
# Recording values for koszalin, city #321.
# Recording values for villacarrillo, city #322.
# Recording values for portland, city #323.
# Recording values for kawalu, city #324.
# Recording values for lavrentiya, city #325.
# Recording values for fairbanks, city #326.
# Recording values for grindavik, city #327.
# Recording values for sambava, city #328.
# Recording values for mulchen, city #329.
# Recording values for mumford, city #330.
# Recording values for oranjemund, city #331.
# Recording values for hasaki, city #332.
# ERROR: could not find record for tabiauea, city #333
# Recording values for bambous virieux, city #334.
# Recording values for eyl, city #335.
# Recording values for alghero, city #336.
# ERROR: could not find record for camana, city #337
# Recording values for dover, city #338.
# Recording values for amazar, city #339.
# Recording values for mehendiganj, city #340.
# ERROR: could not find record for attawapiskat, city #341
# Recording values for baykit, city #342.
# Recording values for broska, city #343.
# Recording values for beloha, city #344.
# ERROR: could not find record for mahadday weyne, city #345
# Recording values for hisor, city #346.
# Recording values for luanda, city #347.
# ERROR: could not find record for palabuhanratu, city #348
# Recording values for dudinka, city #349.
# Recording values for dwarka, city #350.
# Recording values for dalvik, city #351.
# Recording values for lodja, city #352.
# Recording values for russell, city #353.
# ERROR: could not find record for kamenskoye, city #354
# Recording values for paamiut, city #355.
# Recording values for mangrol, city #356.
# Recording values for porto velho, city #357.
# Recording values for areosa, city #358.
# ERROR: could not find record for barentsburg, city #359
# Recording values for cairns, city #360.
# Recording values for benghazi, city #361.
# Recording values for montague, city #362.
# ERROR: could not find record for kyra, city #363
# Recording values for yulara, city #364.
# Recording values for mugan, city #365.
# Recording values for zarcero, city #366.
# Recording values for coolum beach, city #367.
# Recording values for chontalpa, city #368.
# Recording values for nanortalik, city #369.
# ERROR: could not find record for novoyegoryevskoye, city #370
# Recording values for riberalta, city #371.
# Recording values for creston, city #372.
# Recording values for ambilobe, city #373.
# Recording values for aklavik, city #374.
# Recording values for bangkalan, city #375.
# Recording values for carballo, city #376.
# Recording values for kahului, city #377.
# ERROR: could not find record for nizhneyansk, city #378
# Recording values for farah, city #379.
# Recording values for orzu, city #380.
# ERROR: could not find record for malakal, city #381
# Recording values for muroto, city #382.
# Recording values for karymskoye, city #383.
# Recording values for saint anthony, city #384.
# Recording values for vredendal, city #385.
# Recording values for stykkisholmur, city #386.
# Recording values for manaus, city #387.
# ERROR: could not find record for aflu, city #388
# Recording values for bhadra, city #389.
# Recording values for awjilah, city #390.
# ERROR: could not find record for ruatoria, city #391
# Recording values for morros, city #392.
# Recording values for broken hill, city #393.
# Recording values for bartlesville, city #394.
# Recording values for olinda, city #395.
# Recording values for emba, city #396.
# Recording values for watsa, city #397.
# Recording values for goderich, city #398.
# Recording values for roald, city #399.
# Recording values for bathsheba, city #400.
# Recording values for chanute, city #401.
# Recording values for santa cruz de la palma, city #402.
# Recording values for clyde river, city #403.
# Recording values for taquaritinga, city #404.
# Recording values for santa helena, city #405.
# Recording values for morgantown, city #406.
# Recording values for port lincoln, city #407.
# Recording values for sisimiut, city #408.
# Recording values for esperance, city #409.
# Recording values for kunming, city #410.
# Recording values for laguna, city #411.
# Recording values for xai-xai, city #412.
# Recording values for dombasle-sur-meurthe, city #413.
# Recording values for maniitsoq, city #414.
# Recording values for astoria, city #415.
# Recording values for carbonia, city #416.
# Recording values for nandurbar, city #417.
# Recording values for quatre cocos, city #418.
# Recording values for mayo, city #419.
# Recording values for nioro, city #420.
# Recording values for union city, city #421.
# Recording values for golkoy, city #422.
# Recording values for parrita, city #423.
# Recording values for port-gentil, city #424.
# Recording values for harper, city #425.
# Recording values for fez, city #426.
# Recording values for san martin, city #427.
# ERROR: could not find record for irbil, city #428
# Recording values for sneek, city #429.
# Recording values for voznesenye, city #430.
# Recording values for monte alegre, city #431.
# Recording values for labuhan, city #432.
# Recording values for wooster, city #433.
# Recording values for kalat, city #434.
# Recording values for chervonohryhorivka, city #435.
# Recording values for tursunzoda, city #436.
# Recording values for mbini, city #437.
# Recording values for pangnirtung, city #438.
# Recording values for vygonichi, city #439.
# Recording values for ossora, city #440.
# Recording values for yashkino, city #441.
# Recording values for tarpon springs, city #442.
# Recording values for yaan, city #443.
# Recording values for vestmanna, city #444.
# Recording values for kudahuvadhoo, city #445.
# Recording values for port augusta, city #446.
# Recording values for atikokan, city #447.
# Recording values for synya, city #448.
# Recording values for roma, city #449.
# Recording values for cap malheureux, city #450.
# Recording values for suntar, city #451.
# Recording values for taoudenni, city #452.
# Recording values for talnakh, city #453.
# Recording values for valdivia, city #454.
# Recording values for leh, city #455.
# ERROR: could not find record for mys shmidta, city #456
# ERROR: could not find record for formoso do araguaia, city #457
# Recording values for tazovskiy, city #458.
# Recording values for portel, city #459.
# Recording values for namatanai, city #460.
# Recording values for fiumicino, city #461.
# Recording values for ketchikan, city #462.
# Recording values for westport, city #463.
# ERROR: could not find record for shirvan, city #464
# Recording values for preobrazheniye, city #465.
# Recording values for richards bay, city #466.
# Recording values for kiknur, city #467.
# Recording values for shakhtinsk, city #468.
# Recording values for tautira, city #469.
# ERROR: could not find record for pemangkat, city #470
# Recording values for salinopolis, city #471.
# ERROR: could not find record for bargal, city #472
# ERROR: could not find record for stornoway, city #473
# Recording values for black river, city #474.
# ERROR: could not find record for krasnoselkup, city #475
# Recording values for buala, city #476.
# Recording values for kavaratti, city #477.
# ERROR: could not find record for mutsamudu, city #478
# Recording values for arlit, city #479.
# ERROR: could not find record for warqla, city #480
# Recording values for nizhniy kuranakh, city #481.
# Recording values for vestmannaeyjar, city #482.
# Recording values for severo-yeniseyskiy, city #483.
# Recording values for surt, city #484.
# Recording values for nelson bay, city #485.
# Recording values for revda, city #486.
# Recording values for north bend, city #487.
# Recording values for harrison, city #488.
# Recording values for amiens, city #489.
# Recording values for sao joao do piaui, city #490.
# Recording values for los llanos de aridane, city #491.
# ERROR: could not find record for balimo, city #492
# Recording values for ilebo, city #493.
# Recording values for luwingu, city #494.
# ERROR: could not find record for satitoa, city #495
# Recording values for san cristobal, city #496.
# Recording values for seoul, city #497.
# Recording values for belozerskoye, city #498.
# Recording values for borogontsy, city #499.
# Recording values for luwuk, city #500.
# Recording values for vardo, city #501.
# Recording values for tupi paulista, city #502.
# Recording values for teknaf, city #503.
# Recording values for hanchuan, city #504.
# Recording values for stonewall, city #505.
# Recording values for geraldton, city #506.
# Recording values for baisha, city #507.
# Recording values for itaituba, city #508.
# Recording values for evensk, city #509.
# Recording values for bushehr, city #510.
# Recording values for altamira, city #511.
# Recording values for kangasala, city #512.
# Recording values for rawson, city #513.
# Recording values for la macarena, city #514.
# Recording values for port-cartier, city #515.
# Recording values for lazaro cardenas, city #516.
# Recording values for shiraz, city #517.
# Recording values for qasigiannguit, city #518.
# Recording values for aketi, city #519.
# Recording values for abay, city #520.
# Recording values for spencer, city #521.
# Recording values for santiago del estero, city #522.
# Recording values for la rioja, city #523.
# Recording values for san vicente, city #524.
# Recording values for chapais, city #525.
# ERROR: could not find record for buariki, city #526
# Recording values for panzhihua, city #527.
# Recording values for san blas, city #528.
# Recording values for oyotun, city #529.
# Recording values for ewa beach, city #530.
# Recording values for gilgit, city #531.
# Recording values for beringovskiy, city #532.
# Recording values for oyama, city #533.
# ERROR: could not find record for astipalaia, city #534
# Recording values for matamoros, city #535.
# Recording values for lerwick, city #536.
# Recording values for kanungu, city #537.
# Recording values for kailua, city #538.
# ERROR: could not find record for ksenyevka, city #539
# Recording values for pestravka, city #540.
# Recording values for mizdah, city #541.
# Recording values for fortuna, city #542.
# Recording values for aykhal, city #543.
# Recording values for chumikan, city #544.
# Recording values for adrar, city #545.
# Recording values for birao, city #546.
# Recording values for atherton, city #547.
# Recording values for bondeno, city #548.
# ERROR: could not find record for ituni, city #549
# Recording values for la asuncion, city #550.
# Recording values for casper, city #551.
# Recording values for yurimaguas, city #552.
# Recording values for ust-tsilma, city #553.
# Recording values for kabinda, city #554.
# Recording values for xiaoweizhai, city #555.
# ERROR: could not find record for usevya, city #556
# Recording values for vikhorevka, city #557.
# Recording values for zharkent, city #558.
# Recording values for shahr-e babak, city #559.
# Recording values for virginia beach, city #560.
# Recording values for abu kamal, city #561.
# ERROR: could not find record for jyvaskyla, city #562
# Recording values for bandarbeyla, city #563.
# Recording values for tura, city #564.
# Recording values for mankono, city #565.
# Recording values for auchinleck, city #566.
# Recording values for altay, city #567.
# Recording values for kovdor, city #568.
# Recording values for wageningen, city #569.
# Recording values for bagotville, city #570.
# Recording values for nairobi, city #571.
# Recording values for yamada, city #572.
# Recording values for la romana, city #573.
# Recording values for ormara, city #574.
# Recording values for agirish, city #575.
# Recording values for noumea, city #576.
# Recording values for pucallpa, city #577.
# ERROR: could not find record for ndele, city #578
# Recording values for puerto narino, city #579.
# Recording values for carutapera, city #580.
# Recording values for front royal, city #581.
# Recording values for smithers, city #582.
# Recording values for petropavlovsk-kamchatskiy, city #583.
# Recording values for husavik, city #584.
# Recording values for boma, city #585.
# Recording values for phan thiet, city #586.
# Recording values for ankang, city #587.
# Recording values for alofi, city #588.
# Recording values for sorland, city #589.
# Recording values for sur, city #590.
# Recording values for bambanglipuro, city #591.
# Recording values for nalut, city #592.
# Recording values for angoche, city #593.
# Recording values for aswan, city #594.
# Recording values for ust-nera, city #595.
# Recording values for gryfino, city #596.
# Recording values for nouakchott, city #597.
# Recording values for camacha, city #598.
# ERROR: could not find record for grimari, city #599
# Recording values for pringsewu, city #600.
# Recording values for calabasas, city #601.
# Recording values for kutum, city #602.
# Recording values for merauke, city #603.
# Recording values for nantucket, city #604.
# Recording values for kharan, city #605.
# Recording values for santa lucia, city #606.
# Recording values for egvekinot, city #607.
# Recording values for waddan, city #608.
# Recording values for sao filipe, city #609.
# Recording values for palmer, city #610.
# Recording values for morshansk, city #611.
# Recording values for dalbandin, city #612.
# Recording values for santa cruz, city #613.
# Recording values for hirara, city #614.
# Recording values for yepifan, city #615.
# Recording values for cockburn town, city #616.
# Recording values for helena, city #617.
# ERROR: could not find record for pahuatlan, city #618
# ERROR: could not find record for solsvik, city #619
# Recording values for barhi, city #620.
# Recording values for champerico, city #621.
# ERROR: could not find record for yuzhno-yeniseyskiy, city #622
# Recording values for la ronge, city #623.

# %%
len(Lat)
# Out:
# 554

# %%
len(Lon)
# Out:
# 554

# %%
len(Name)
# Out:
# 554

# %%
len(Max_Temp)
# Out:
# 554

# %%
len(Cloudiness)
# Out:
# 554

# %%
len(Humidity)
# Out:
# 554

# %%
len(Wind_Speed)
# Out:
# 554

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame(Name, columns=['Name'])
df['Lat'] = Lat
df['Lon'] = Lon
df['Temp'] = Max_Temp
df['Cloudiness'] = Cloudiness
df['Humidity'] = Humidity
df['Wind'] = Wind_Speed

# %%
df
# Out:
#                  Name    Lat     Lon    Temp  Cloudiness  Humidity   Wind
# 0          mahibadhoo   3.78   72.97   82.01          93      76.0   3.03
# 1            klaksvik  62.23   -6.59   51.80          90     100.0   1.00
# 2         zhangjiakou  40.77  114.88   50.51           0      60.0   1.26
# 3             solwezi -12.18   26.40   57.17           0      42.0   3.13
# 4              atuona  -9.80 -139.03   79.49           5      72.0   8.65
# 5              torbay  47.66  -52.73   59.00          20      82.0   3.60
# 6               muros  42.77   -9.06   69.80          75      93.0   4.60
# 7              barrow -38.31  -60.23   48.71          35      75.0   4.60
# 8             margate -43.03  147.26   51.80          75      66.0   4.60
# 9        punta arenas -53.16  -70.91   41.00           0      65.0   3.60
# 10            rikitea -23.12 -134.97   69.95         100      69.0   5.97
# 11            mataura -46.19  168.86   34.67           1      90.0   2.25
# 12             hobart -42.88  147.33   51.80          75      66.0   4.60
# 13           tasiilaq  65.61  -37.64   50.00           5      53.0   6.20
# 14               hilo  19.71 -155.08   82.40          90      74.0   2.60
# 15               naze   5.43    7.07   75.17         100      89.0   1.80
# 16       oktyabrskoye  56.73   85.44   53.60          40     100.0   1.00
# 17              sitka  37.17  -99.65  102.17           0      17.0   4.99
# 18            madaoua  14.07    5.96   86.69         100      53.0   3.30
# 19             dikson  73.51   80.55   44.03         100     100.0   1.58
# 20          sao pedro  41.13   -7.96   68.00          20     100.0   1.90
# 21           cidreira -30.17  -50.22   72.11          84      62.0   2.48
# 22               nome  30.04  -94.42   91.40          40      62.0   3.10
# 23               nehe  48.48  124.88   51.77          85      92.0   2.83
# 24   velyka pysarivka  50.43   35.48   61.31         100      95.0   3.57
# 25          jamestown -33.21  138.60   45.47          73      93.0   7.25
# 26             ouango   4.31   22.55   67.79         100      93.0   1.03
# 27          busselton -33.64  115.35   57.53         100      67.0   5.95
# 28     port elizabeth  39.31  -74.98   89.60           1      70.0   3.60
# 29     severo-kurilsk  50.68  156.12   49.25           2      92.0   5.30
# ..                ...    ...     ...     ...         ...       ...    ...
# 524               sur  22.57   59.53   79.67          28      63.0   6.09
# 525     bambanglipuro  -7.95  110.28   74.27          33      82.0   6.81
# 526             nalut  31.86   10.98   74.27           0      56.0   4.55
# 527           angoche -16.23   39.91   67.43           0      84.0   2.39
# 528             aswan  24.09   32.90   95.15           0      12.0   5.90
# 529          ust-nera  64.57  143.24   59.33         100      49.0   1.30
# 530           gryfino  53.25   14.49   69.80           0      56.0   3.10
# 531        nouakchott  18.08  -15.98   78.80          40      83.0   6.20
# 532           camacha  33.08  -16.33   71.60          40      78.0   4.60
# 533         pringsewu  -5.36  104.98   70.13          76      91.0   1.14
# 534         calabasas  34.14 -118.64   82.40           1      42.0   3.10
# 535             kutum  14.20   24.66   79.31          84      58.0   1.15
# 536           merauke  -8.49  140.40   77.69         100      85.0   8.66
# 537         nantucket  41.28  -70.10   78.80           1      88.0   5.70
# 538            kharan  28.58   65.42   81.11           0      11.0   2.02
# 539       santa lucia  41.98   12.66   73.40           0      78.0   1.00
# 540         egvekinot  66.32 -179.17   45.83         100      62.0   1.53
# 541            waddan  29.16   16.14   77.87           0      49.0   6.59
# 542        sao filipe  14.90  -24.50   76.07         100      81.0   4.37
# 543            palmer -34.85  139.16   53.60          75      81.0  11.30
# 544         morshansk  53.44   41.81   66.35          95      73.0   3.23
# 545         dalbandin  28.90   64.41   70.31           0      12.0   1.50
# 546        santa cruz  -6.22  -36.02   75.35          10      54.0   5.40
# 547            hirara  24.80  125.28   80.60          75      94.0   1.50
# 548           yepifan  53.83   38.55   62.39          99      97.0   2.78
# 549     cockburn town  21.46  -71.14   83.27           0      78.0   6.65
# 550            helena  46.59 -112.04   55.40          90      71.0   6.86
# 551             barhi  24.31   85.42   84.20          75      83.0   1.63
# 552        champerico  16.38  -93.60   93.20          40      44.0   1.00
# 553          la ronge  55.10 -105.30   51.80          90      93.0   8.20
#
# [554 rows x 7 columns]

# %%
df.to_csv('results.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.scatter(Lat, Max_Temp, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Max Temperature (8/17/2019)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.savefig('Temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.scatter(Lat, Humidity, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Humidity (8/17/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.scatter(Lat, Cloudiness, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Cloudiness (8/17/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.scatter(Lat, Wind_Speed, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Wind Speed (8/17/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.savefig('Wind.png')

# %% [markdown]
# Just to state the obvious, weather data is enormously complex, and any rigorous attempt to understand it would need to use typical meterological data and account for time of year, time of day, etc. Since I'm using the free account of the API, this study doesn't even attempt to do that...

# %% [markdown]
# # Observations

# %% [markdown]
# 1. Temperature generally rises as Latitude approaches the equator, but the highest temperatures recorded are slightly North. This is likely due to cities in Northern Africa and could be confirmed by comparing with Longitude.
#
#
# 2. Humidity is recorded near 100% across Latitudes. While not specified in the API, it is clear from the values approaching 100 that this is a measurement of relative (not absolute) humidity. If it were absolute humidity, we would likely see the highest values near the equator. Not that some of the lowest values for Humidity are just north of the equator, and are likely the same cities with the highest temperature (which would confirm the hypothesis that these cities are in Northern Africa). Again, these could be easily confirmed through additional exploration.
#
#
# 3. While the results from Wind Speed are certainly not strong enough to be conclusive, there is a suggstion of higher wind speeds in the far northern and southern latitudes. 10 m/s winds are very strong, and 16 m/s winds are extreme. Wind speeds have enormous fluctuations throughout the day (let alone the year), so it would be interesting to collect more hourly data for these cities, from either EPW or TMY files, and develop a fuller understanding of these patterns.
